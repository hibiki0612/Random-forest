# %%
import pandas as pd
import datetime
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import optuna.integration.lightgbm as lgb
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
train_path = 'train.csv'
test_path = 'test.csv'

# %%
train = pd.read_csv(train_path)
test = pd.read_csv(test_path)

# %%
train.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
test.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# 1          7        1             0     0
# 2         10        0             1     1
# 3          7        1             1     0
# 4          7        1             0     1
#
# [5 rows x 21 columns]

# %%
print (train_data.columns.values)
# Out:
# ['battery_power' 'blue' 'clock_speed' 'dual_sim' 'fc' 'four_g'
#  'int_memory' 'm_dep' 'mobile_wt' 'n_cores' 'pc' 'px_height' 'px_width'
#  'ram' 'sc_h' 'sc_w' 'talk_time' 'three_g' 'touch_screen' 'wifi']

# %%
x_imp=train.loc[:,['battery_power','px_height','px_width','ram']].values
y = train["price_range"].values


x_train,x_test,y_train,y_test = train_test_split(x_imp,y,test_size=0.3,random_state=1234)

# %%
train_data = train.drop("price_range",axis=1)
y = train["price_range"].values
x = train_data.values

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=1234)

# %%
from sklearn.ensemble import RandomForestRegressor as RFR
rf = RFR(n_estimators=80, max_features='auto')
rf.fit(x, y)

f, ax = plt.subplots(figsize=(11, 15))
sns.barplot(x=rf.feature_importances_, y=train_data.columns.values, orient='h')
# Out:
# <AxesSubplot:>

# %%
clf = RandomForestClassifier(n_estimators=100,random_state=1234)
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=1234)

# %%
pred = clf.predict(x_test)

# %%
print('score=',clf.score(x_test,y_test))
# Out:
# score= 0.9166666666666666

# %%
#特徴量の標準化
x_train = (x_train - x_train.mean()) / x_train.std()
x_test = (x_test - x_test.mean()) / x_test.std()

# %%
from sklearn.model_selection import GridSearchCV
rfr_grid = GridSearchCV(clf,cv=5,param_grid = {'n_estimators':[10,25,50,100,],
              'min_samples_split':[0.5,2,4,10],
              'min_samples_leaf':[1,2,4,10],
              'max_features':[2,4,8],
              'bootstrap':[True, False]
              })
 
rfr_grid = rfr_grid.fit(x_train, y_train)
rfr_grid_best = rfr_grid.best_estimator_
# Out:
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
# ...
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 171, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 171, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 171, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 171, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 171, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 903, in fit
#     super().fit(
#   File "/Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/hibiki/miniforge3/envs/my-env/lib/python3.9/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.52857143 0.52785714 0.55714286 0.56071429 0.88571429 0.89857143
#  0.90571429 0.90857143 0.87785714 0.89571429 0.90214286 0.905
#  0.88928571 0.89357143 0.89285714 0.89857143 0.52857143 0.52785714
#  0.55714286 0.56071429 0.88785714 0.89285714 0.89785714 0.90785714
#  0.88785714 0.89285714 0.89785714 0.90785714 0.88428571 0.89357143
#  0.89857143 0.9        0.52857143 0.52785714 0.55714286 0.56071429
#  0.88571429 0.89857143 0.89714286 0.90142857 0.88571429 0.89857143
#  0.89714286 0.90142857 0.88642857 0.89285714 0.89       0.9
#  0.52857143 0.52785714 0.55714286 0.56071429 0.87285714 0.87428571
#  0.87428571 0.87928571 0.87285714 0.87428571 0.87428571 0.87928571
#  0.87285714 0.87428571 0.87428571 0.87928571 0.55571429 0.56214286
#  0.55357143 0.55571429 0.885      0.895      0.89357143 0.89642857
#  0.88428571 0.895      0.89714286 0.89714286 0.87785714 0.88785714
#  0.885      0.885      0.55571429 0.56214286 0.55357143 0.55571429
#  0.885      0.895      0.89571429 0.89928571 0.885      0.895
#  0.89571429 0.89928571 0.88142857 0.88642857 0.88642857 0.88928571
#  0.55571429 0.56214286 0.55357143 0.55571429 0.88285714 0.88928571
#  0.88571429 0.88928571 0.88285714 0.88928571 0.88571429 0.88928571
#  0.88214286 0.89142857 0.885      0.88785714 0.55571429 0.56214286
#  0.55357143 0.55571429 0.87285714 0.87642857 0.87285714 0.87142857
#  0.87285714 0.87642857 0.87285714 0.87142857 0.87285714 0.87642857
#  0.87285714 0.87142857        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.65214286 0.64928571 0.67       0.69857143 0.89071429 0.885
#  0.88928571 0.89071429 0.90071429 0.90285714 0.89928571 0.89714286
#  0.88785714 0.89       0.88357143 0.88714286 0.65214286 0.64928571
#  0.67       0.69857143 0.89142857 0.895      0.89642857 0.89428571
#  0.89142857 0.895      0.89642857 0.89428571 0.88714286 0.88714286
#  0.88857143 0.89214286 0.65214286 0.64928571 0.67       0.69857143
#  0.87857143 0.88428571 0.88928571 0.89285714 0.87857143 0.88428571
#  0.88928571 0.89285714 0.88285714 0.89714286 0.89785714 0.89285714
#  0.65214286 0.64928571 0.67       0.69857143 0.87714286 0.88
#  0.88214286 0.885      0.87714286 0.88       0.88214286 0.885
#  0.87714286 0.88       0.88214286 0.885      0.64785714 0.64785714
#  0.64785714 0.64785714 0.86285714 0.86428571 0.86214286 0.865
#  0.86285714 0.86285714 0.86571429 0.865      0.85357143 0.85214286
#  0.85285714 0.85214286 0.64785714 0.64785714 0.64785714 0.64785714
#  0.86214286 0.86214286 0.86285714 0.86285714 0.86214286 0.86214286
#  0.86285714 0.86285714 0.855      0.85571429 0.85571429 0.85571429
#  0.64785714 0.64785714 0.64785714 0.64785714 0.85428571 0.855
#  0.85428571 0.85428571 0.85428571 0.855      0.85428571 0.85428571
#  0.85071429 0.85       0.85       0.85       0.64785714 0.64785714
#  0.64785714 0.64785714 0.84       0.84       0.84       0.84
#  0.84       0.84       0.84       0.84       0.84       0.84
#  0.84       0.84              nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# best params =  {'bootstrap': True, 'max_features': 2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %%
print("best params = ",rfr_grid.best_params_)
# Out:
# best params =  {'bootstrap': True, 'max_features': 2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %%
clf_best = RFR(n_estimators=100,
                max_features = 2,
                min_samples_split = 2,
                min_samples_leaf = 1,
                bootstrap = True,
                random_state = 1234)
clf_best.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_features=2, random_state=1234)

# %%
y_pred_cfr_best = clf_best.predict(x_test)

# %%
print('score=',clf_best.score(x_test,y_test))
# Out:
# score= 0.9485334786642765

# %%
RFC.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_leaf_nodes=44,
#                        min_samples_split=9)

# %%
import lightgbm as lgb

model = lgb.LGBMClassifier(bootstrap=True)

# %%
model.fit(x_train,y_train)
# Out:
# [LightGBM] [Warning] Unknown parameter: bootstrap
# LGBMClassifier(bootstrap=True)

# %%
pred = model.predict(x_test)

# %%
print('score=',model.score(x_test,y_test))
# Out:
# score= 0.9183333333333333

# %%
# 目的関数の定義（最小値問題として定式化する。）
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
def objective(trial):
    min_samples_split = trial.suggest_int("min_samples_split", 8, 16)
    max_leaf_nodes = int(trial.suggest_discrete_uniform("max_leaf_nodes", 4, 64, 4))
    criterion = trial.suggest_categorical("criterion", ["gini", "entropy"])
    
    RFC = RandomForestClassifier(min_samples_split = min_samples_split, 
                                max_leaf_nodes = max_leaf_nodes,
                                criterion = criterion)
    RFC.fit(x_train, y_train)
    return 1.0 - accuracy_score(y_test, RFC.predict(x_test))

# %%
import optuna
study = optuna.create_study()
study.optimize(objective, n_trials = 100)
# Out:
# [I 2021-06-05 23:52:40,715] A new study created in memory with name: no-name-4d1d9cff-1454-45e2-8f3c-9ac2cd82ea88
# [I 2021-06-05 23:52:40,871] Trial 0 finished with value: 0.1466666666666666 and parameters: {'min_samples_split': 12, 'max_leaf_nodes': 28.0, 'criterion': 'gini'}. Best is trial 0 with value: 0.1466666666666666.
# [I 2021-06-05 23:52:41,028] Trial 1 finished with value: 0.1333333333333333 and parameters: {'min_samples_split': 10, 'max_leaf_nodes': 56.0, 'criterion': 'entropy'}. Best is trial 1 with value: 0.1333333333333333.
# [I 2021-06-05 23:52:41,116] Trial 2 finished with value: 0.21833333333333338 and parameters: {'min_samples_split': 10, 'max_leaf_nodes': 4.0, 'criterion': 'gini'}. Best is trial 1 with value: 0.1333333333333333.
# [I 2021-06-05 23:52:41,245] Trial 3 finished with value: 0.15833333333333333 and parameters: {'min_samples_split': 11, 'max_leaf_nodes': 28.0, 'criterion': 'gini'}. Best is trial 1 with value: 0.1333333333333333.
# [I 2021-06-05 23:52
and parameters: {'min_samples_split': 11, 'max_leaf_nodes': 56.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:50,026] Trial 58 finished with value: 0.13 and parameters: {'min_samples_split': 12, 'max_leaf_nodes': 64.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:50,189] Trial 59 finished with value: 0.14833333333333332 and parameters: {'min_samples_split': 10, 'max_leaf_nodes': 60.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:50,320] Trial 60 finished with value: 0.15333333333333332 and parameters: {'min_samples_split': 11, 'max_leaf_nodes': 20.0, 'criterion': 'gini'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:50,526] Trial 61 finished with value: 0.13666666666666671 and parameters: {'min_samples_split': 12, 'max_leaf_nodes': 60.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:50,726] Trial 62 finished with value: 0.14500000000000002 and parameters: {'min_samples_split': 12, 'max_leaf_nodes': 52.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:50,896] Trial 63 finished with value: 0.14166666666666672 and parameters: {'min_samples_split': 13, 'max_leaf_nodes': 64.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:51,063] Trial 64 finished with value: 0.14 and parameters: {'min_samples_split': 11, 'max_leaf_nodes': 60.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:51,227] Trial 65 finished with value: 0.1316666666666667 and parameters: {'min_samples_split': 12, 'max_leaf_nodes': 52.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:51,385] Trial 66 finished with value: 0.13666666666666671 and parameters: {'min_samples_split': 14, 'max_leaf_nodes': 56.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:51,537] Trial 67 finished with value: 0.15000000000000002 and parameters: {'min_samples_split': 13, 'max_leaf_nodes': 48.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:51,699] Trial 68 finished with value: 0.1433333333333333 and parameters: {'min_samples_split': 11, 'max_leaf_nodes': 64.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:51,863] Trial 69 finished with value: 0.14833333333333332 and parameters: {'min_samples_split': 13, 'max_leaf_nodes': 40.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:52,032] Trial 70 finished with value: 0.1383333333333333 and parameters: {'min_samples_split': 12, 'max_leaf_nodes': 60.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:52,211] Trial 71 finished with value: 0.14166666666666672 and parameters: {'min_samples_split': 12, 'max_leaf_nodes': 64.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:52,367] Trial 72 finished with value: 0.14500000000000002 and parameters: {'min_samples_split': 8, 'max_leaf_nodes': 44.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:52,520] Trial 73 finished with value: 0.1466666666666666 and parameters: {'min_samples_split': 9, 'max_leaf_nodes': 36.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:52,694] Trial 74 finished with value: 0.1316666666666667 and parameters: {'min_samples_split': 12, 'max_leaf_nodes': 60.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:52,860] Trial 75 finished with value: 0.14166666666666672 and parameters: {'min_samples_split': 12, 'max_leaf_nodes': 64.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:53,033] Trial 76 finished with value: 0.1466666666666666 and parameters: {'min_samples_split': 13, 'max_leaf_nodes': 56.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:53,201] Trial 77 finished with value: 0.1433333333333333 and parameters: {'min_samples_split': 11, 'max_leaf_nodes': 56.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:53,365] Trial 78 finished with value: 0.1333333333333333 and parameters: {'min_samples_split': 10, 'max_leaf_nodes': 60.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:53,508] Trial 79 finished with value: 0.15333333333333332 and parameters: {'min_samples_split': 10, 'max_leaf_nodes': 32.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:53,663] Trial 80 finished with value: 0.1383333333333333 and parameters: {'min_samples_split': 13, 'max_leaf_nodes': 52.0, 'criterion': 'gini'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:53,833] Trial 81 finished with value: 0.1316666666666667 and parameters: {'min_samples_split': 9, 'max_leaf_nodes': 52.0, 'criterion': 'entropy'}. Best is trial 18 with value: 0.1233333333333333.
# [I 2021-06-05 23:52:53,982] Trial 82 finished with value: 0.1216666666666667 and parameters: {'min_samples_split': 9, 'max_leaf_nodes': 44.0, 'criterion': 'entropy'}. Best is trial 82 with value: 0.1216666666666667.
# [I 2021-06-05 23:52:54,155] Trial 83 finished with value: 0.13 and parameters: {'min_samples_split': 9, 'max_leaf_nodes': 44.0, 'criterion': 'entropy'}. Best is trial 82 with value: 0.1216666666666667.
# [I 2021-06-05 23:52:54,324] Trial 84 finished with value: 0.1466666666666666 and parameters: {'min_samples_split': 9, 'max_leaf_nodes': 44.0, 'criterion': 'entropy'}. Best is trial 82 with value: 0.1216666666666667.
# [I 2021-06-05 23:52:54,501] Trial 85 finished with value: 0.14 and parameters: {'min_samples_split': 8, 'max_leaf_nodes': 40.0, 'criterion': 'entropy'}. Best is trial 82 with value: 0.1216666666666667.
# [I 2021-06-05 23:52:54,658] Trial 86 finished with value: 0.15833333333333333 and parameters: {'min_samples_split': 9, 'max_leaf_nodes': 44.0, 'criterion': 'entropy'}. Best is trial 82 with value: 0.1216666666666667.
# [I 2021-06-05 23:52:54,823] Trial 87 finished with value: 0.14 and parameters: {'min_samples_split': 8, 'max_leaf_nodes': 40.0, 'criterion': 'entropy'}. Best is trial 82 with value: 0.1216666666666667.
# [I 2021-06-05 23:52:54,986] Trial 88 finished with value: 0.135 and parameters: {'min_samples_split': 10, 'max_leaf_nodes': 48.0, 'criterion': 'entropy'}. Best is trial 82 with value: 0.1216666666666667.
# [I 2021-06-05 23:52:55,180] Trial 89 finished with value: 0.13 and parameters: {'min_samples_split': 15, 'max_leaf_nodes': 48.0, 'criterion': 'entropy'}. Best is trial 82 with value: 0.1216666666666667.
# [I 2021-06-05 23:52:55,364] Trial 90 finished with value: 0.16333333333333333 and parameters: {'min_samples_split': 16, 'max_leaf_nodes': 48.0, 'criterion': 'entropy'}. Best is trial 82 with value: 0.1216666666666667.
# [I 2021-06-05 23:52:55,520] Trial 91 finished with value: 0.135 and parameters: {'min_samples_split': 16, 'max_leaf_nodes': 48.0, 'criterion': 'entropy'}. Best is trial 82 with value: 0.1216666666666667.
# [I 2021-06-05 23:52:55,681] Trial 92 finished with value: 0.1333333333333333 and parameters: {'min_samples_split': 9, 'max_leaf_nodes': 44.0, 'criterion': 'entropy'}. Best is trial 82 with value: 0.1216666666666667.
# [I 2021-06-05 23:52:55,832] Trial 93 finished with value: 0.1433333333333333 and parameters: {'min_samples_split': 12, 'max_leaf_nodes': 36.0, 'criterion': 'entropy'}. Best is trial 82 with value: 0.1216666666666667.
# [I 2021-06-05 23:52:56,011] Trial 94 finished with value: 0.1316666666666667 and parameters: {'min_samples_split': 15, 'max_leaf_nodes': 64.0, 'criterion': 'entropy'}. Best is trial 82 with value: 0.1216666666666667.
# [I 2021-06-05 23:52:56,178] Trial 95 finished with value: 0.14833333333333332 and parameters: {'min_samples_split': 11, 'max_leaf_nodes': 56.0, 'criterion': 'entropy'}. Best is trial 82 with value: 0.1216666666666667.
# [I 2021-06-05 23:52:56,348] Trial 96 finished with value: 0.15000000000000002 and parameters: {'min_samples_split': 9, 'max_leaf_nodes': 44.0, 'criterion': 'entropy'}. Best is trial 82 with value: 0.1216666666666667.
# [I 2021-06-05 23:52:56,506] Trial 97 finished with value: 0.14500000000000002 and parameters: {'min_samples_split': 9, 'max_leaf_nodes': 40.0, 'criterion': 'entropy'}. Best is trial 82 with value: 0.1216666666666667.
# [I 2021-06-05 23:52:56,677] Trial 98 finished with value: 0.15000000000000002 and parameters: {'min_samples_split': 15, 'max_leaf_nodes': 52.0, 'criterion': 'entropy'}. Best is trial 82 with value: 0.1216666666666667.
# [I 2021-06-05 23:52:56,859] Trial 99 finished with value: 0.1283333333333333 and parameters: {'min_samples_split': 10, 'max_leaf_nodes': 44.0, 'criterion': 'entropy'}. Best is trial 82 with value: 0.1216666666666667.

# %%
study.best_params    # 求めたハイパーパラメータ
# Out:
# {'min_samples_split': 9, 'max_leaf_nodes': 44.0, 'criterion': 'entropy'}

# %%
RFC = RandomForestClassifier(min_samples_split = 9, 
                                max_leaf_nodes = 44,
                                criterion = 'entropy')

# %%
print('score=',RFC.score(x_test,y_test))
# Out:
# score= 0.8983333333333333

# %%
x_imp=train.loc[:,['battery_power','px_height','px_width','ram']]
y = train["price_range"]

# %%
1.0 - study.best_value
# Out:
# 0.8783333333333333

# %%
org_sort = np.argsort(-rf.feature_importances_)
 
#f, ax = plt.subplots(figsize=(11, 19))
#sns.barplot(rf.feature_importances_[org_sort], y=X_train.columns.values[org_sort], orient='h')
 
X_train = train.iloc[:,org_sort[:4]]

# %%
#目的変数と説明変数の2変量の関係を描画
fig = plt.figure(figsize=(20,20))

for i in range(4):
    
    ax = fig.add_subplot(2,2,i+1)
    
    sns.regplot(x=X_train.iloc[:,i], y=y)

plt.tight_layout()
plt.show()
